# %%
import numpy as np
import pandas as pd

# %%
business = pd.read_csv('yelp_business.csv')

# %%
business
# Out:
#                    business_id  \
# 0       FYWN1wneV18bWNgQjJ2GNg
# 1       He-G7vWjzVUysIKrfNbPUQ
# 2       KQPW8lFf1y5BT2MxiSZ3QA
# 3       8DShNS-LuFqpEWIp0HxijA
# 4       PfOCPjBrlQAnz__NXj9h_w
# 5       o9eMRCWt5PkpLDE0gOPtcQ
# 6       kCoE3jvEtg6UVz5SOD3GVw
# 7       OD2hnuuTJI9uotcKycxg1A
# 8       EsMcGiZaQuG1OOvL9iUFug
# 9       TGWhGNusxyMaA4kQVBNeew
# 10      XOSRcvtaKc_Q5H1SAzN20A
# 11      Y0eMNa5C-YU1RQOZf9XvVA
# 12      xcgFnd-MwkZeO5G2HQ0gAQ
# 13      NmZtoE3v8RdSJEczYbMT9g
# 14      fNMVV_ZX7CJSDWQGdOM8Nw
# 15      l09JfMeQ6ynYs5MCJtrcmQ
# 16      IQSlT5jGE6CCDhSG0zG3xg
# 17      b2I2DXtZVnpUMCXp1JON7A
# 18      0FMKDOU8TJT1x87OKYGDTg
# 19      Gu-xs3NIQTj3Mj2xYoN2aw
# 20      lHYiCS-y8AFjUitv6MGpxg
# 21      94KziT6DQ9XlBET3WzIv_w
# 22      7YIy1tXOor9VCwvaSjuBHg
# 23      PMH4oUa-bWELKogdtkWewg
# 24      VSGcuYDV3q-AAZ9ZPq4fBQ
# 25      1K4qrnfyzKzGgJPBEcJaNQ
# 26      VBHEsoXQb2AQ76J9l8h1uQ
# 27      AtdXq_gu9NTE5rx4ct_dGg
# 28      Dj0S-Oe4ytRJzMGUPgYUkw
# ...

# %%
business['state'].value_counts()
# Out:
# AZ     52214
# NV     33086
# ON     30208
# NC     12956
# OH     12609
# PA     10109
# QC      8169
# WI      4754
# EDH     3795
# BW      3118
# IL      1852
# SC       679
# MLN      208
# HLD      179
# NYK      152
# CHE      143
# FIF       85
# ELN       47
# WLN       38
# C         28
# NY        18
# ESX       12
# ST        11
# NI        10
# 01        10
# VS         7
# SCB        5
# CA         5
# XGL        4
# BY         4
#        ...
# FLN        2
# CMA        2
# VT         2
# KHL        1
# PKN        1
# TAM        1
# DE         1
# RCC        1
# CS         1
# MN         1
# VA         1
# MT         1
# 30         1
# 3          1
# NLK        1
# GA         1
# FAL        1
# ZET        1
# HU         1
# SL         1
# WA         1
# AB         1
# FL         1
# AL         1
# B          1
# STG        1
# NE         1
# WHT        1
# KY         1
# AK         1
# Name: state, Length: 67, dtype: int64

# %%
len(business)
# Out:
# 174567

# %%
len(business[business['state']=='AZ'])
# Out:
# 52214

# %%
business = business[business['state']=='AZ']

# %%
business
# Out:
#                    business_id  \
# 0       FYWN1wneV18bWNgQjJ2GNg
# 2       KQPW8lFf1y5BT2MxiSZ3QA
# 3       8DShNS-LuFqpEWIp0HxijA
# 11      Y0eMNa5C-YU1RQOZf9XvVA
# 16      IQSlT5jGE6CCDhSG0zG3xg
# 18      0FMKDOU8TJT1x87OKYGDTg
# 21      94KziT6DQ9XlBET3WzIv_w
# 22      7YIy1tXOor9VCwvaSjuBHg
# 31      zzMu-6SmqhpvHxVRM6tx9g
# 36      ok38fApaT1TBEU-IH85BvA
# 39      A_Ij4SwFmlRbVtRnsdSzWA
# 43      5qpi5VQ_S2Itm8xvRm1k8Q
# 45      rDMptJYWtnMhpQu_rRXHng
# 46      1WBkAuQg81kokZIPMpn9Zg
# 66      d6ngz4WmMaQL8Xdfur7bwQ
# 71      c6Shr51XcbvAeXp6hb_Exg
# 72      iPa__LOhse-hobC2Xmp-Kw
# 73      XPZT3zLrkLkFSkBVxSsM3w
# 78      EfYExaDrwhj0k611u5lYMg
# 79      AZUCA3oiGou2wLnAYG1P6g
# 80      kKx8iCJkomVQBdWHnmmOiA
# 88      YhV93k9uiMdr3FlV4FHjwA
# 92      dA7KJReGl9PMi3Tg_mBHuw
# 93      GX83LORhO99mdNFz9_cZdQ
# 95      NVaM_cKKJT3WWyP21PANzw
# 99      VZ37HCZVruFm-w_Mkl1aEQ
# 101     VdlPZg2NAu8t8GkdbPLecg
# 107     QkG3KUXwqZBW18A9k1xqCA
# 119     RV_NgH8wT1TuOs2qNt1WDg
# ...

# %%
business[business['categories'].str.contains("Restaurants")]
# Out:
#                    business_id                                  name  \
# 45      rDMptJYWtnMhpQu_rRXHng                          "McDonald's"
# 46      1WBkAuQg81kokZIPMpn9Zg        "Charr An American Burger Bar"
# 72      iPa__LOhse-hobC2Xmp-Kw                          "McDonald's"
# 80      kKx8iCJkomVQBdWHnmmOiA                "Little Caesars Pizza"
# 88      YhV93k9uiMdr3FlV4FHjwA                     "Caviness Studio"
# 101     VdlPZg2NAu8t8GkdbPLecg        "Tandoori Times Indian Bistro"
# 107     QkG3KUXwqZBW18A9k1xqCA                         "Red Lobster"
# 120     5XejqzaFmtkZMstJS5Iy-w                         "D'Lish Cafe"
# 130     MTH-AcNyWfsBa9sXp04HcQ                      "Firehouse Subs"
# 132     nigYwB_m1TQ1WosjSWi-Hw                      "Simply Burgers"
# 180     2v-8QQfMLX2PCz-0S6gISQ                   "Papa John's Pizza"
# 191     M3uV9Y3EDSpy9d4YwyNSAQ                           "Yakiramen"
# 220     Qv0OEziLJwyAqcgtrTsA4w                   "Luke's Of Chicago"
# ...

# %%
len(business[business['categories'].str.contains("Restaurants")])
# Out:
# 10598

# %%
business = business[business['categories'].str.contains("Restaurants")]

# %%
len(business)
# Out:
# 10598

# %%
business.drop(columns = ["neighborhood"], inplace = True)
# Out:
# C:\Users\Bonnie\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
business
# Out:
#                    business_id                                  name  \
# 45      rDMptJYWtnMhpQu_rRXHng                          "McDonald's"
# 46      1WBkAuQg81kokZIPMpn9Zg        "Charr An American Burger Bar"
# 72      iPa__LOhse-hobC2Xmp-Kw                          "McDonald's"
# 80      kKx8iCJkomVQBdWHnmmOiA                "Little Caesars Pizza"
# 88      YhV93k9uiMdr3FlV4FHjwA                     "Caviness Studio"
# 101     VdlPZg2NAu8t8GkdbPLecg        "Tandoori Times Indian Bistro"
# 107     QkG3KUXwqZBW18A9k1xqCA                         "Red Lobster"
# 120     5XejqzaFmtkZMstJS5Iy-w                         "D'Lish Cafe"
# 130     MTH-AcNyWfsBa9sXp04HcQ                      "Firehouse Subs"
# 132     nigYwB_m1TQ1WosjSWi-Hw                      "Simply Burgers"
# 180     2v-8QQfMLX2PCz-0S6gISQ                   "Papa John's Pizza"
# 191     M3uV9Y3EDSpy9d4YwyNSAQ                           "Yakiramen"
# 220     Qv0OEziLJwyAqcgtrTsA4w                   "Luke's Of Chicago"
# ...

# %%
business.to_csv('filteredbusiness.csv')
